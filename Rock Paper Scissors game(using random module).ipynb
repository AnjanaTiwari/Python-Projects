# %%
# Rock vs Paper->paper wins
# Rock vs scissor->Rock wins
# paper vs scissor -> scissor wins

# %%
import random as re
print("""
Please select any one option
1. rock
2. Scissor
3. paper""")
l1=["rock","paper","scissor"]

while True:
    ccount=0
    ucount=0
    u=int(input("""
Game Start.....
1. Yes
2. No | Exit
    
    """))
    if u ==1:
        for a in range(1,6):
            print(f"{a} attemppt.\n")
            userinput=int(input("""
                1. rock
                2. scissor
                3. paper
            """))
            if userinput == 1:
                uchoice = "rock"
            elif userinput == 2:
                uchoice = "scissor"
            elif userinput == 3:
                uchoice ="paper"
            else:
                print("Invalid condition ")
            cchoice=re.choice(l1)
            if cchoice==uchoice:
                print("UserChoice:-",uchoice)
                print("ComputerChoice:-",cchoice)
                print("Game Draw")
#                 ucount=ucount
#                 ccount=ccount
                
            elif (uchoice=="rock" and cchoice=="scissor") or (uchoice =="paper" and cchoice =="rock") or (uchoice=="scissor" and cchoice=="paper"):       
                print("UserChoice:-",uchoice)
                print("ComputerChoice:-",cchoice)
                print("User bhaiyya jeet gaya re baba!")
                ucount+=1
                
            else:
                print("UserChoice:-",uchoice)
                print("ComputerChoice:-",cchoice)
                print("Computer is win")
                ccount+=1
        
        if ucount==ccount:
                    print("\nFinal Game Draw...")
                    print("User Score", ucount)
                    print("Computer score",ccount)
        elif ucount>ccount:
                    print("Final You Win The Game...")
                    print("User Score", ucount)
                    print("Computer score",ccount)
        else:
                    print("Final Computet Win The Game...")
                    print("User Score", ucount)
                    print("Computer score",ccount)     
    else:
        break
# Out:
# Please select any one option
# 1. rock
# 2. Scissor
# 3. paper
#
# Game Start.....
# 1. Yes
# 2. No | Exit
#
#     1
# 1 attemppt.
#
#
#                 1. rock
#                 2. scissor
#                 3. paper
#             1
# UserChoice:- rock
# ComputerChoice:- scissor
# User bhaiyya jeet gaya re baba!
# 2 attemppt.
#
#
#                 1. rock
#                 2. scissor
#                 3. paper
#             3
# UserChoice:- paper
# ComputerChoice:- scissor
# Computer is win
# 3 attemppt.
#
#
#                 1. rock
#                 2. scissor
#                 3. paper
#             1
# UserChoice:- rock
# ComputerChoice:- scissor
# User bhaiyya jeet gaya re baba!
# 4 attemppt.
#
#
#                 1. rock
#                 2. scissor
#                 3. paper
#             1
# UserChoice:- rock
# ComputerChoice:- paper
# Computer is win
# 5 attemppt.
#
#
#                 1. rock
#                 2. scissor
#                 3. paper
#             3
# ...
